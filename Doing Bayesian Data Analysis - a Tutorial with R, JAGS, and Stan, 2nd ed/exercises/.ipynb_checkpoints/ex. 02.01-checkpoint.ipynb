# %% [markdown]
# # Exercise 02.01

# %% [markdown]
# ## Problem:

# %% [markdown]
# **[Purpose: To get you actively manipulating mathematical models of probabilities.]**
#
# Suppose we have a four-sided die from a board game. On a tetrahedral die, each face is an equilateral triangle. When you roll the die, it lands with one face down and the other three faces visible as a three-sided pyramid. The faces are numbered 1-4, with the value of the bottom face printed (as clustered dots) at the bottom edges of all three visible faces. Denote the value of the bottom face as x. Consider the following three mathematical descriptions of the probabilities of $x$. Model A: $p(x) = 1/4$. Model B: $p(x) = x/10$. Model C: $p(x) = 12/(25x)$. For each model, determine the value of $p(x)$ for each value of $x$. Describe in words what kind of bias (or lack of bias) is expressed by each model.

# %% [markdown]
# ## Solution:

# %% [markdown]
# Model A:

# %% [markdown]
# $p(1) = 1/4$ <br/>
# $p(2) = 1/4$ <br/>
# $p(3) = 1/4$ <br/>
# $p(4) = 1/4$ <br/>
#
# Model is unbiased.

# %%
x = seq(from = 1, to = 4, by = 1)
pxA = rep(1/4, length(x))
plot(x, pxA, col = "black", type = "p", ylim = c(0, 1),
     main = "Model A",
     xlab = "side",
     ylab = "probability (p(x))")
# Out:
# Plot with title “Model A”

# %% [markdown]
# Model B:

# %% [markdown]
# $p(1) = \frac{1}{10}$ <br/>
# $p(2) = \frac{2}{10}$ <br/>
# $p(3) = \frac{3}{10}$ <br/>
# $p(4) = \frac{4}{10}$ <br/>
#
# Model is linearly biased towards higher numbers (3 and 4).

# %%
pxB = x/10
plot(x, pxB, col = "black", type = "p", ylim = c(0, 1),
     main = "Model B",
     xlab = "side",
     ylab = "probability (p(x))")
# Out:
# Plot with title “Model B”

# %% [markdown]
# Model C:

# %% [markdown]
# $p(1) = \frac{12}{25(1)} = \frac{12}{25}$ <br/>
# $p(2) = \frac{12}{25(2)} = \frac{6}{25}$ <br/>
# $p(3) = \frac{12}{25(3)} = \frac{4}{25}$ <br/>
# $p(4) = \frac{12}{25(4)} = \frac{3}{25}$ <br/>
#
# Model is biased towards lower numbers (1 and 2).

# %%
pxC = 12/(25*x)
plot(x, pxC, col = "black", type = "p", ylim = c(0, 1),
     main = "Model C",
     xlab = "side",
     ylab = "probability (p(x))")
# Out:
# Plot with title “Model C”
