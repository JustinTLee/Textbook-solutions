# %% [markdown]
# # Exercise 03.02

# %% [markdown]
# ## Problem:

# %% [markdown]
# **[Purpose: Being able to record and communicate the results of your analyses.]**
#
# Open the program ExamplesOfR.R. At the end, notice the section that produces a simple graph. Your job is to save the graph so you can incorporate it into documents in the future, as you would for reporting actual data analyses. Save the graph in a format that is compatible with your word processing software. Import the saved file into your document and explain, in text, what you did. (Notice that for some word processing systems you could merely copy and paste directly from R’s graphic window to the document window. But the problem with this approach is that you have no other record of the graph produced by the analysis. We want the graph to be saved separately so that it can be incorporated into various reports at a future time.)

# %% [markdown]
# ## Solution:

# %% [markdown]
# Relevant code from ExamplesofR.R:

# %%
####################################################################
# opening graphics windows and saving graphs
source("../DBDA2Eprograms/DBDA2E-utilities.R")   # read defn. of openGraph, saveGraph
openGraph(width = 3, height = 4)                 # open a graphics window
plot(x = 1:4, y = c(1, 3, 2, 4), type = "o",     # make a plot in the screen window
     main = "temp plot",
     xlab = "x",
     ylab = "y")
saveGraph(file = "../images/temp", type = "png")           # save the graph as "temp.png"
# Out:
# *********************************************************************
# Kruschke, J. K. (2015). Doing Bayesian Data Analysis, Second Edition:
# A Tutorial with R, JAGS, and Stan. Academic Press / Elsevier.
# *********************************************************************
# Warning message in install.packages(want[!have]):
# “installation of package ‘rjags’ had non-zero exit status”Warning message in install.packages(want[!have]):
# “installation of package ‘runjags’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Loading required package: coda
# Plot with title “temp plot”
